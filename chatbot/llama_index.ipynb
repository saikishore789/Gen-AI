# %%
# !pip install -U -q llama-index llama-index-llms-groq

# %%
import os
from llama_index.core.llms import ChatMessage, MessageRole
from llama_index.llms.groq import Groq

# %%
os.environ["GROQ_API_KEY"] = ""

# %%
llm = Groq(
    model="llama-3.3-70b-versatile",
    temperature=0
)

# %%
def chat():
    history = [
        ChatMessage(role=MessageRole.SYSTEM, content="You are a helpful assistant. Be concise and accurate.")
    ]

    print("LlamaIndex Chatbot. Type 'exit' to quit.\n")

    while True:
        user_input = input("You: ").strip()
        if user_input.lower() in {"exit", "quit"}:
            break

        # add user message
        history.append(ChatMessage(role=MessageRole.USER, content=user_input))

        # call LLM with full history
        resp = llm.chat(messages=history)  # ChatResponse
        answer = resp.message.content

        print(f"Bot: {answer}\n")

        # add assistant message
        history.append(ChatMessage(role=MessageRole.ASSISTANT, content=answer))

        print("-"*80)

# %%
chat()
# Out:
# LlamaIndex Chatbot. Type 'exit' to quit.
# You:  explain llama index with examples
# Bot: The Llama Index is not a widely recognized term, but I'll assume you're referring to the Llama2 index, a concept related to the Llama AI model.
#
# However, I found that the term "Llama Index" might be related to a different concept. In some contexts, the Llama Index could be an example of a "Llama Index" used in data analysis or information retrieval.
#
# Assuming the Llama Index is similar to other indexing methods, here's a simplified explanation:
#
# **What is an Index?**
# An index is a data structure that improves the speed of data retrieval by providing a quick way to locate specific data.
#
# **Llama Index Example:**
# Suppose we have a collection of documents, and we want to create an index to quickly find documents containing specific words.
#
# | Document ID | Document Text |
# | --- | --- |
# | 1 | The quick brown fox |
# | 2 | The sun is shining |
# | 3 | The fox is very quick |
#
# **Llama Index:**
#
# | Word | Document IDs |
# | --- | --- |
# | The | 1, 2, 3 |
# | quick | 1, 3 |
# | brown | 1 |
# | fox | 1, 3 |
# | sun | 2 |
# | is | 2, 3 |
# | shining | 2 |
# | very | 3 |
#
# In this example, the Llama Index is a table that maps words to the document IDs where they appear. This allows for fast lookup of documents containing specific words.
#
# Please note that this is a simplified example, and actual indexing methods can be more complex and optimized for specific use cases.
#
# If you have any further information or context about the Llama Index, I'll be happy to provide a more accurate explanation.
#
# --------------------------------------------------------------------------------
