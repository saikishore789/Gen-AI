# %%
# !pip install -q -U langchain-community

# %% [markdown]
# Open AI

# %%
# !pip install -q -U langchain-openai

# %%
import os
from langchain_openai import ChatOpenAI

api_key = os.getenv("GOOGLE_API_KEY")

llm = ChatOpenAI(
    model="gpt-3.5-turbo",
    temperature=0,
)

response = llm.invoke("What is Machine Learning")

print(response.content)

# %% [markdown]
# Ollama

# %%
# !pip install -q -U langchain-ollama

# %%
# !ollama list
# Out:
# ]11;?\NAME           ID              SIZE      MODIFIED
# llama3.2:1b    baf6a787fdff    1.3 GB    7 weeks ago

# %%
import os
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model="llama3.2:1b",
    temperature=0,
)

response = llm.invoke("What is Langchain and differenece between langchain and LLM")

print(response.content)
# Out:
# LangChain is a type of large language model (LLM) that uses a novel architecture to generate human-like text. It's designed to be more efficient, scalable, and flexible than traditional LLMs.
#
# Here are the key differences between LangChain and other types of LLMs:
#
# 1. **Architecture**: LangChain uses a transformer-based architecture with a modified encoder-decoder structure, which allows for better handling of long-range dependencies and contextual understanding.
# 2. **Training data**: LangChain is trained on a massive dataset of text from various sources, including books, articles, and websites. This enables it to learn patterns and relationships in language that are not present in traditional LLMs.
# 3. **Self-supervised learning**: LangChain uses self-supervised learning techniques, such as masked language modeling and next sentence prediction, which allow it to learn from its own output without explicit human feedback.
# 4. **Parallelization**: LangChain is designed to be parallelized, allowing it to process multiple inputs simultaneously and scale up to large datasets.
# 5. **Efficiency**: LangChain is optimized for performance and efficiency, making it suitable for real-time applications such as chatbots, virtual assistants, and content generation.
#
# Compared to other types of LLMs, LangChain has several advantages:
#
# * **Improved contextual understanding**: LangChain's transformer architecture allows it to better understand the context of a sentence or paragraph, leading to more accurate and informative responses.
# * **Increased flexibility**: LangChain can handle a wide range of input formats and styles, making it suitable for applications such as content generation, language translation, and text summarization.
# * **Better handling of long-range dependencies**: LangChain's architecture is better equipped to handle long-range dependencies in language, leading to more coherent and natural-sounding responses.
#
# However, LangChain also has some limitations:
#
# * **Limited domain knowledge**: While LangChain can be trained on a wide range of domains, its domain-specific knowledge may not be as strong as that of traditional LLMs.
# * **Dependence on training data quality**: The quality of the training data used to train LangChain can significantly impact its performance and accuracy.
#
# In summary, LangChain is a novel architecture for large language models that offers improved contextual understanding, flexibility, and efficiency. While it has some limitations, it has the potential to revolutionize various applications in natural language processing.
